# %% [markdown]
# <a href="https://colab.research.google.com/github/niaparamita/tugas_01_Array/blob/main/saol_1(hasil%20codingan).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sistem Sederhana Pengelola Nilai Mahasiswa dengan Array

# %%
import numpy as np
import matplotlib.pyplot as plt

# Input 10 data
print("Nilai Mahasiswa: ")
nilaimahasiswa = np.array([89,90,80,55,79,98,95,91,85,60])
nil = np.array(nilaimahasiswa)
print(nil)

# Data Nilai Tertinggi, Terendah, Dan Rata-Rata
nilaitertinggi = np.max(nil)
print("Nilai tertinggi:", nilaitertinggi)
nilaiterendah = np.min(nil)
print("Nilai terendah:", nilaiterendah)
ratarata = np.mean(nil)
print("Rata-rata:", ratarata)

# Data Lulus dan Tidak Lulus
lulus = [n for n in nil if n >= 60]
tidak_lulus = [n for n in nil if n < 60]
Jlulus = len(lulus)
Jtidaklulus = len(tidak_lulus)
print(f"Jumlah Lulus   : {Jlulus}")
print(f"Tidak Lulus    : {Jtidaklulus}")

# Grafik Nilai Mahasiswa
plt.bar(range(len(nil)), nil)
plt.xlabel("Mahasiswa")
plt.ylabel("Nilai")
plt.title("Grafik Nilai Mahasiswa")
plt.show()


# Grafik Kelulusan Mahasiswa
labels = ["Lulus", "Tidak Lulus"]
sizes = Jlulus, Jtidaklulus
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=180)
plt.title("Grafik Data Kelulusan Mahasiswa")
plt.axis('equal')
plt.show()
# Out:
# Nilai Mahasiswa:
# [89 90 80 55 79 98 95 91 85 60]
# Nilai tertinggi: 98
# Nilai terendah: 55
# Rata-rata: 82.2
# Jumlah Lulus   : 9
# Tidak Lulus    : 1
